# %%
import pandas as pd
import io

df = pd.read_csv(io.BytesIO(uploaded['ideal (2).csv']))
print(df)
# Out:
#         x        y1        y2         y3        y4         y5        y6  \
# 0   -20.0 -0.912945  0.408082   9.087055  5.408082  -9.087055  0.912945
# 1   -19.9 -0.867644  0.497186   9.132356  5.497186  -9.132356  0.867644
# 2   -19.8 -0.813674  0.581322   9.186326  5.581322  -9.186326  0.813674
# 3   -19.7 -0.751573  0.659649   9.248426  5.659649  -9.248426  0.751573
# 4   -19.6 -0.681964  0.731386   9.318036  5.731386  -9.318036  0.681964
# ..    ...       ...       ...        ...       ...        ...       ...
# 395  19.5  0.605540  0.795815  10.605540  5.795815 -10.605540 -0.605540
# 396  19.6  0.681964  0.731386  10.681964  5.731386 -10.681964 -0.681964
# 397  19.7  0.751573  0.659649  10.751574  5.659649 -10.751574 -0.751573
# 398  19.8  0.813674  0.581322  10.813674  5.581322 -10.813674 -0.813674
# 399  19.9  0.867644  0.497186  10.867644  5.497186 -10.867644 -0.867644
#
#            y7        y8        y9  ...        y41        y42       y43  \
# ...

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-031a8136-6a33-4516-b8a7-7e84f28856fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-031a8136-6a33-4516-b8a7-7e84f28856fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-72011737-9ef3-4eed-89a6-6c7f3c1832f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-72011737-9ef3-4eed-89a6-6c7f3c1832f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

df = pd.read_csv(io.BytesIO(uploaded['test (2).csv']))
print(df)
# Out:
#        x          y
# 0   17.5  34.161040
# 1    0.3   1.215102
# 2   -8.7 -16.843908
# 3  -19.2 -37.170870
# 4  -11.0 -20.263054
# ..   ...        ...
# 95  -1.9  -4.036904
# 96  12.2  -0.010358
# 97  16.5 -33.964134
# 98   5.3 -10.291622
# 99  17.9  28.078455
#
# [100 rows x 2 columns]

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-0d1fe135-e368-4d52-992c-62aecfc06cbd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d1fe135-e368-4d52-992c-62aecfc06cbd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

df = pd.read_csv(io.BytesIO(uploaded['train (2).csv']))
print(df)
# Out:
#         x         y1         y2         y3        y4
# 0   -20.0  39.778572 -40.078590 -20.214268 -0.324914
# 1   -19.9  39.604813 -39.784000 -20.070950 -0.058820
# 2   -19.8  40.099070 -40.018845 -19.906782 -0.451830
# 3   -19.7  40.151100 -39.518402 -19.389118 -0.612044
# 4   -19.6  39.795662 -39.360065 -19.815890 -0.306076
# ..    ...        ...        ...        ...       ...
# 395  19.5 -38.254158  39.661987  19.536741  0.695158
# 396  19.6 -39.106945  39.067880  19.840752  0.638423
# 397  19.7 -38.926495  40.211475  19.516634  0.109105
# 398  19.8 -39.276672  40.038870  19.377943  0.189025
# 399  19.9 -39.724934  40.558865  19.630678  0.513824
#
# [400 rows x 5 columns]

# %%
print(train_data.columns)
print(test_data.columns)
print(ideal_functions.columns)
# Out:
# Index(['x', 'y1', 'y2', 'y3', 'y4'], dtype='object')
# Index(['x', 'y'], dtype='object')
# Index(['x', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10', 'y11',
#        'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y20', 'y21',
#        'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y30', 'y31',
#        'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y40', 'y41',
#        'y42', 'y43', 'y44', 'y45', 'y46', 'y47', 'y48', 'y49', 'y50'],
#       dtype='object')

# %%
train_data = pd.read_csv('train (2).csv')
test_data = pd.read_csv('test (2).csv')
ideal_functions = pd.read_csv('ideal (2).csv')

# %%
chosen_ideal_functions = []
for i in range(4):
    min_deviation = float('inf')
    chosen_function = None

# %%
def least_square_regression(x, y):
    A = np.vstack([x, np.ones(len(x))]).T
    m, c = np.linalg.lstsq(A, y, rcond=None)[0]
    return m, c

def calculate_deviation(x, y, m, c):
    predicted_y = m * x + c
    deviation = y - predicted_y
    return deviation

# %%
chosen_ideal_functions = []
for i in range(4):
    min_deviation = float('inf')
    chosen_function = None

# %%
for index, row in ideal_functions.iterrows():
    m, c = least_square_regression(train_data['x'], train_data['y1'])
    deviations = calculate_deviation(train_data['x'], train_data['y1'], m, c)
    sum_squared_deviation = np.sum(deviations**2)

# %%
print(ideal_functions.columns)
# Out:
# Index(['x', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10', 'y11',
#        'y12', 'y13', 'y14', 'y15', 'y16', 'y17', 'y18', 'y19', 'y20', 'y21',
#        'y22', 'y23', 'y24', 'y25', 'y26', 'y27', 'y28', 'y29', 'y30', 'y31',
#        'y32', 'y33', 'y34', 'y35', 'y36', 'y37', 'y38', 'y39', 'y40', 'y41',
#        'y42', 'y43', 'y44', 'y45', 'y46', 'y47', 'y48', 'y49', 'y50'],
#       dtype='object')

# %%
for index, row in ideal_functions.iterrows():
    m, c = least_square_regression(train_data['x'], train_data['y1'])
    deviations = calculate_deviation(train_data['x'], train_data['y1'], m, c)
    sum_squared_deviation = np.sum(deviations**2)

    if sum_squared_deviation < min_deviation:
        min_deviation = sum_squared_deviation
        chosen_function = row['function']

# %%
for index, row in ideal_functions.iterrows():
        m, c = least_square_regression(train_data['x'], train_data['y1'])
        deviations = calculate_deviation(train_data['x'], train_data['y1'], m, c)
        sum_squared_deviation = np.sum(deviations**2)

        if sum_squared_deviation < min_deviation:
            min_deviation = sum_squared_deviation
            chosen_function = row['Function']

   choosen_ideal_functions.append(chosen_function))
    ideal_functions = ideal_functions[ideal_functions['Function'] != chosen_function]
# Out:
#   File "<tokenize>", line 10
#     choosen_ideal_functions.append(chosen_function))
#     ^
# IndentationError: unindent does not match any outer indentation level
